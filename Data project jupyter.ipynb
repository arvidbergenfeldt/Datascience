# %%
#Jupyter change

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data_c = pd.read_csv('countries_data.csv')
print(data_c.head())
sns.relplot('GDP','Lifeexpect',  hue = 'Country', data = data_c)
plt.show()
# Out:
#   Country  Year  Lifeexpect           GDP
# 0   Chile  2000        77.3  7.786093e+10
# 1   Chile  2001        77.3  7.097992e+10
# 2   Chile  2002        77.8  6.973681e+10
# 3   Chile  2003        77.9  7.564346e+10
# 4   Chile  2004        78.0  9.921039e+10
# c:\Users\olofs\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Chile

plt.figure(figsize=(10,8))
sns.scatterplot('Lifeexpect', 'GDP', data = data_c[data_c.Country == 'Chile'])
ax = plt.subplot()
#ax.set_xticks('Lifeexpect')
#ax.set_xticklabels('ye')

plt.title('Country: Chile')




plt.show()
# Out:
# c:\Users\olofs\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
